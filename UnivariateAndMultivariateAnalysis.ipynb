# %% [markdown]
# <a href="https://colab.research.google.com/github/sseyler0119/Data-Science-Projects/blob/master/UnivariateAndMultivariateAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diamonds = sns.load_dataset('diamonds')

# %%
# examine the data
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
# describe the data
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %% [markdown]
# Perform univariate analysis

# %%
# total number of carats by cut
sns.countplot(x = 'cut', data=diamonds[diamonds['carat']== True])

# %%
diamonds['carat'].hist(bins=10, figsize=(10,7.5))

# %%
carat = diamonds['carat']
sns.set(rc={"figure.figsize":(10, 7.5)}) # set figure size
p = sns.distplot(carat,
                color='#6bb2e4',
                hist_kws=dict(edgecolor='#356d94', linewidth=2),
                bins=25,
                kde=True,
                kde_kws=dict(shade=True))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
p = sns.stripplot(x=carat, dodge=True, palette='Blues',
                 jitter = True)

# %%
p = sns.violinplot(x=diamonds['carat'], inner='box', color='#f15b2a', saturation=0.65)

# %%
diamonds.drop(['x', 'y', 'z'], axis=1, inplace=True) # view correlation between carat and price, drop x,y,z columns
corrmat = diamonds.corr()
f, ax = plt.subplots(figsize=(10,9))

sns.heatmap(corrmat, ax=ax, cmap="YlGnBu", linewidths=0.2)

# %%
fig, ax = plt.subplots(figsize=(10, 10)) # compare price per carat, categorized by cut and size
sns.scatterplot(x="carat", y="price", hue="cut", size="clarity", data=diamonds, alpha=0.8)

# %%
# compare carat per cut, categorized by price
fig, ax = plt.subplots(figsize=(10, 7))
sns.scatterplot(x="carat", y="cut", hue="price", size="depth", data=diamonds)
